# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dft-road-casualty-statistics-accident-last-5-years.csv")
df
# Out:
# C:\Users\bchen\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0,2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        accident_index  accident_year accident_reference  \
# 0       2016010000005           2016          010000005
# 1       2016010000006           2016          010000006
# 2       2016010000008           2016          010000008
# 3       2016010000016           2016          010000016
# 4       2016010000018           2016          010000018
# ...               ...            ...                ...
# 597968  2020991027064           2020          991027064
# 597969  2020991029573           2020          991029573
# 597970  2020991030297           2020          991030297
# 597971  2020991030900           2020          991030900
# 597972  2020991032575           2020          991032575
#
# ...

# %%
df.shape
# Out:
# (597973, 36)

# %%
df.isnull().sum()
# Out:
# accident_index                                   0
# accident_year                                    0
# accident_reference                               0
# location_easting_osgr                          123
# location_northing_osgr                         123
# longitude                                      133
# latitude                                       133
# police_force                                     0
# accident_severity                                0
# number_of_vehicles                               0
# number_of_casualties                             0
# date                                             0
# day_of_week                                      0
# time                                             0
# local_authority_district                         0
# local_authority_ons_district                     0
# local_authority_highway                          0
# first_road_class                                 0
# ...

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# accident_index                                 0
# accident_year                                  0
# accident_reference                             0
# location_easting_osgr                          0
# location_northing_osgr                         0
# longitude                                      0
# latitude                                       0
# police_force                                   0
# accident_severity                              0
# number_of_vehicles                             0
# number_of_casualties                           0
# date                                           0
# day_of_week                                    0
# time                                           0
# local_authority_district                       0
# local_authority_ons_district                   0
# local_authority_highway                        0
# first_road_class                               0
# first_road_number                              0
# ...

# %%
df.shape
# Out:
# (597803, 36)

# %%
df.dtypes
# Out:
# accident_index                                  object
# accident_year                                    int64
# accident_reference                              object
# location_easting_osgr                          float64
# location_northing_osgr                         float64
# longitude                                      float64
# latitude                                       float64
# police_force                                     int64
# accident_severity                                int64
# number_of_vehicles                               int64
# number_of_casualties                             int64
# date                                            object
# day_of_week                                      int64
# time                                            object
# local_authority_district                         int64
# local_authority_ons_district                    object
# local_authority_highway                         object
# ...

# %%
df.columns
# Out:
# Index(['accident_index', 'accident_year', 'accident_reference',
#        'location_easting_osgr', 'location_northing_osgr', 'longitude',
#        'latitude', 'police_force', 'accident_severity', 'number_of_vehicles',
#        'number_of_casualties', 'date', 'day_of_week', 'time',
#        'local_authority_district', 'local_authority_ons_district',
#        'local_authority_highway', 'first_road_class', 'first_road_number',
#        'road_type', 'speed_limit', 'junction_detail', 'junction_control',
#        'second_road_class', 'second_road_number',
#        'pedestrian_crossing_human_control',
#        'pedestrian_crossing_physical_facilities', 'light_conditions',
#        'weather_conditions', 'road_surface_conditions',
#        'special_conditions_at_site', 'carriageway_hazards',
#        'urban_or_rural_area', 'did_police_officer_attend_scene_of_accident',
#        'trunk_road_flag', 'lsoa_of_accident_location'],
#       dtype='object')

# %%
columns=['accident_year',
       'longitude',
       'latitude', 'police_force', 'accident_severity', 'number_of_vehicles',
       'number_of_casualties', 'date', 'day_of_week', 'time',
       'local_authority_district', 'local_authority_ons_district',
       'local_authority_highway', 'first_road_class', 'first_road_number',
       'road_type', 'speed_limit', 'junction_detail', 'junction_control',
       'second_road_class', 'second_road_number',
       'pedestrian_crossing_human_control',
       'pedestrian_crossing_physical_facilities', 'light_conditions',
       'weather_conditions', 'road_surface_conditions',
       'special_conditions_at_site', 'carriageway_hazards',
       'urban_or_rural_area', 'did_police_officer_attend_scene_of_accident'
       ]
df[columns]
# Out:
#         accident_year  longitude   latitude  police_force  accident_severity  \
# 0                2016  -0.279323  51.584754             1                  3
# 1                2016   0.184928  51.449595             1                  3
# 2                2016  -0.473837  51.543563             1                  3
# 3                2016  -0.164442  51.404958             1                  3
# 4                2016  -0.406580  51.483139             1                  3
# ...               ...        ...        ...           ...                ...
# 597968           2020  -2.926320  56.473539            99                  2
# 597969           2020  -4.267565  55.802353            99                  3
# 597970           2020  -2.271903  57.186317            99                  2
# 597971           2020  -3.968753  55.950940            99                  3
# 597972           2020  -4.561040  56.003843            99                  3
#
# ...

# %%
dfselect=df[columns]

# %%
columns_category=[
       'accident_severity', 
       'local_authority_district', 'local_authority_ons_district',
       'local_authority_highway', 'first_road_class', 'first_road_number',
       'road_type',  'junction_detail', 'junction_control',
       'second_road_class', 'second_road_number',
       'pedestrian_crossing_human_control',
       'pedestrian_crossing_physical_facilities', 'light_conditions',
       'weather_conditions', 'road_surface_conditions',
       'special_conditions_at_site', 'carriageway_hazards',
       'urban_or_rural_area', 'did_police_officer_attend_scene_of_accident'
       ]
columns_time=[
      'date',  'time'
       ]
for n in columns_category:
    dfselect[n]=dfselect[n].astype("category")
dfselect['date'] = pd.to_datetime(dfselect['date'], format="%d/%m/%Y")
dfselect['time'] = pd.to_datetime(dfselect['time'], format="%H:%M").dt.hour
# Out:
# <ipython-input-12-a51b891f89c9>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfselect[n]=dfselect[n].astype("category")
# <ipython-input-12-a51b891f89c9>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfselect['date'] = pd.to_datetime(dfselect['date'], format="%d/%m/%Y")
# <ipython-input-12-a51b891f89c9>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
dfselect.dtypes
# Out:
# accident_year                                           int64
# longitude                                             float64
# latitude                                              float64
# police_force                                            int64
# accident_severity                                    category
# number_of_vehicles                                      int64
# number_of_casualties                                    int64
# date                                           datetime64[ns]
# day_of_week                                             int64
# time                                                    int64
# local_authority_district                             category
# local_authority_ons_district                         category
# local_authority_highway                              category
# first_road_class                                     category
# first_road_number                                    category
# ...

# %%
dfselect
# Out:
#         accident_year  longitude   latitude  police_force accident_severity  \
# 0                2016  -0.279323  51.584754             1                 3
# 1                2016   0.184928  51.449595             1                 3
# 2                2016  -0.473837  51.543563             1                 3
# 3                2016  -0.164442  51.404958             1                 3
# 4                2016  -0.406580  51.483139             1                 3
# ...               ...        ...        ...           ...               ...
# 597968           2020  -2.926320  56.473539            99                 2
# 597969           2020  -4.267565  55.802353            99                 3
# 597970           2020  -2.271903  57.186317            99                 2
# 597971           2020  -3.968753  55.950940            99                 3
# 597972           2020  -4.561040  56.003843            99                 3
#
# ...

# %%
dfselect
# Out:
#         accident_year  longitude   latitude  police_force accident_severity  \
# 0                2016  -0.279323  51.584754             1                 3
# 1                2016   0.184928  51.449595             1                 3
# 2                2016  -0.473837  51.543563             1                 3
# 3                2016  -0.164442  51.404958             1                 3
# 4                2016  -0.406580  51.483139             1                 3
# ...               ...        ...        ...           ...               ...
# 597968           2020  -2.926320  56.473539            99                 2
# 597969           2020  -4.267565  55.802353            99                 3
# 597970           2020  -2.271903  57.186317            99                 2
# 597971           2020  -3.968753  55.950940            99                 3
# 597972           2020  -4.561040  56.003843            99                 3
#
# ...

# %%
dfselect.dtypes
# Out:
# accident_year                                           int64
# longitude                                             float64
# latitude                                              float64
# police_force                                            int64
# accident_severity                                    category
# number_of_vehicles                                      int64
# number_of_casualties                                    int64
# date                                           datetime64[ns]
# day_of_week                                             int64
# time                                                    int64
# local_authority_district                             category
# local_authority_ons_district                         category
# local_authority_highway                              category
# first_road_class                                     category
# first_road_number                                    category
# ...

# %%
df.dtypes
# Out:
# accident_index                                  object
# accident_year                                    int64
# accident_reference                              object
# location_easting_osgr                          float64
# location_northing_osgr                         float64
# longitude                                      float64
# latitude                                       float64
# police_force                                     int64
# accident_severity                                int64
# number_of_vehicles                               int64
# number_of_casualties                             int64
# date                                            object
# day_of_week                                      int64
# time                                            object
# local_authority_district                         int64
# local_authority_ons_district                    object
# local_authority_highway                         object
# ...

# %%
df["time"]
# Out:
# 0         02:30
# 1         00:37
# 2         01:25
# 3         09:15
# 4         07:53
#           ...
# 597968    14:30
# 597969    15:05
# 597970    12:42
# 597971    14:00
# 597972    13:50
# Name: time, Length: 597803, dtype: object

# %%
dfselect.describe(include="all",percentiles=[0.01,0.05,0.1,0.9,0.95,0.99])["speed_limit"]
# Out:
# <ipython-input-19-4fd068697c3c>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   dfselect.describe(include="all",percentiles=[0.01,0.05,0.1,0.9,0.95,0.99])["speed_limit"]
# count     597803.000000
# unique              NaN
# top                 NaN
# freq                NaN
# first               NaN
# last                NaN
# mean          37.136077
# std           14.026402
# min           -1.000000
# 1%            20.000000
# 5%            20.000000
# 10%           30.000000
# 50%           30.000000
# 90%           60.000000
# 95%           70.000000
# 99%           70.000000
# max           70.000000
# Name: speed_limit, dtype: float64

# %%
dfselect[dfselect["did_police_officer_attend_scene_of_accident"]==3]
# Out:
#         accident_year  longitude   latitude  police_force accident_severity  \
# 124              2016   0.212725  51.592694             1                 3
# 176              2016  -0.305226  51.392691             1                 3
# 197              2016   0.022420  51.325440             1                 3
# 205              2016   0.076658  51.537537             1                 3
# 309              2016   0.025860  51.546429             1                 3
# ...               ...        ...        ...           ...               ...
# 587712           2020  -2.575747  51.508549            52                 3
# 587983           2020  -2.506851  51.467784            52                 3
# 588025           2020  -2.528445  51.447853            52                 3
# 589278           2020  -2.142132  51.175066            54                 3
# 589331           2020  -1.807936  51.568424            54                 3
#
# ...

# %%
columns_numeric=dfselect.select_dtypes(include="number").columns

# %%
columns_numeric
# Out:
# Index(['accident_year', 'longitude', 'latitude', 'police_force',
#        'number_of_vehicles', 'number_of_casualties', 'day_of_week', 'time',
#        'speed_limit'],
#       dtype='object')

# %%
columns_numeric =['police_force',
       'number_of_vehicles', 'number_of_casualties', 'day_of_week',
       'speed_limit']

# %%
# Let's make sure we handled all the skewed values
sns.set_style("white")
f, ax = plt.subplots(figsize=(8, 7))
ax = sns.boxplot(data=dfselect[columns_numeric] , orient="h", palette="Set1")
ax.xaxis.grid(False)
ax.set(ylabel="Feature names")
ax.set(xlabel="Numeric values")
ax.set(title="Numeric Distribution of Features")
sns.despine(trim=True, left=True)

# %%
dfselect_object=dfselect.select_dtypes(include='category').columns

# %%
dfselect_object
# Out:
# Index(['accident_severity', 'local_authority_district',
#        'local_authority_ons_district', 'local_authority_highway',
#        'first_road_class', 'first_road_number', 'road_type', 'junction_detail',
#        'junction_control', 'second_road_class', 'second_road_number',
#        'pedestrian_crossing_human_control',
#        'pedestrian_crossing_physical_facilities', 'light_conditions',
#        'weather_conditions', 'road_surface_conditions',
#        'special_conditions_at_site', 'carriageway_hazards',
#        'urban_or_rural_area', 'did_police_officer_attend_scene_of_accident'],
#       dtype='object')

# %%
#for column in dfselect_object:
#    dfselect[column]=dfselect[column].cat.codes

# %%
dfselect
# Out:
#         accident_year  longitude   latitude  police_force accident_severity  \
# 0                2016  -0.279323  51.584754             1                 3
# 1                2016   0.184928  51.449595             1                 3
# 2                2016  -0.473837  51.543563             1                 3
# 3                2016  -0.164442  51.404958             1                 3
# 4                2016  -0.406580  51.483139             1                 3
# ...               ...        ...        ...           ...               ...
# 597968           2020  -2.926320  56.473539            99                 2
# 597969           2020  -4.267565  55.802353            99                 3
# 597970           2020  -2.271903  57.186317            99                 2
# 597971           2020  -3.968753  55.950940            99                 3
# 597972           2020  -4.561040  56.003843            99                 3
#
# ...

# %%
df.dtypes
# Out:
# accident_index                                  object
# accident_year                                    int64
# accident_reference                              object
# location_easting_osgr                          float64
# location_northing_osgr                         float64
# longitude                                      float64
# latitude                                       float64
# police_force                                     int64
# accident_severity                                int64
# number_of_vehicles                               int64
# number_of_casualties                             int64
# date                                            object
# day_of_week                                      int64
# time                                            object
# local_authority_district                         int64
# local_authority_ons_district                    object
# local_authority_highway                         object
# ...

# %%
dfselect=dfselect.drop(['date','accident_year'],axis=1)

# %%
dfselect.columns
# Out:
# Index(['longitude', 'latitude', 'police_force', 'accident_severity',
#        'number_of_vehicles', 'number_of_casualties', 'day_of_week', 'time',
#        'local_authority_district', 'local_authority_ons_district',
#        'local_authority_highway', 'first_road_class', 'first_road_number',
#        'road_type', 'speed_limit', 'junction_detail', 'junction_control',
#        'second_road_class', 'second_road_number',
#        'pedestrian_crossing_human_control',
#        'pedestrian_crossing_physical_facilities', 'light_conditions',
#        'weather_conditions', 'road_surface_conditions',
#        'special_conditions_at_site', 'carriageway_hazards',
#        'urban_or_rural_area', 'did_police_officer_attend_scene_of_accident'],
#       dtype='object')

# %%
dfselect.describe(include='all')
# Out:
#             longitude       latitude   police_force  accident_severity  \
# count   597803.000000  597803.000000  597803.000000           597803.0
# unique            NaN            NaN            NaN                3.0
# top               NaN            NaN            NaN                3.0
# freq              NaN            NaN            NaN           481604.0
# mean        -1.260248      52.425666      28.571901                NaN
# std          1.392037       1.376893      24.913474                NaN
# min         -7.525273      49.912362       1.000000                NaN
# 25%         -2.180568      51.467411       5.000000                NaN
# 50%         -1.143597      51.887986      23.000000                NaN
# 75%         -0.141018      53.380797      45.000000                NaN
# max          1.759641      60.763722      99.000000                NaN
#
#         number_of_vehicles  number_of_casualties    day_of_week  \
# ...

# %%
dfselect['local_authority_ons_district']=dfselect['local_authority_ons_district'].cat.codes

# %%
dfselect['local_authority_highway']=dfselect['local_authority_highway'].cat.codes

# %%
X=dfselect.drop(['accident_severity'],axis=1)

# %%
Y=dfselect[['accident_severity']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test,Y_train, Y_test=train_test_split(X,Y,train_size=0.7,random_state=1234,stratify=Y)

# %%
X_train.shape
# Out:
# (418462, 27)

# %%
X_train.head
# Out:
# <bound method NDFrame.head of         longitude   latitude  police_force  number_of_vehicles  \
# 484171  -0.147489  50.830733            47                   2
# 358143  -0.508465  51.375536            45                   2
# 555586  -1.225555  53.161021            31                   3
# 545141  -0.444252  53.687077            16                   1
# 51062   -1.281776  53.371864            14                   3
# ...           ...        ...           ...                 ...
# 87110    0.115700  51.758053            42                   2
# 405077  -0.265820  51.524522             1                   2
# 572701  -1.104524  50.793103            44                   2
# 51886   -0.440340  54.012161            16                   1
# 568475   0.108984  51.776277            42                   2
#
#         number_of_casualties  day_of_week  time local_authority_district  \
# 484171                     1            3    23                      565
# ...

# %%
Y_train.shape
# Out:
# (418462, 1)

# %%
dfselect.columns
# Out:
# Index(['longitude', 'latitude', 'police_force', 'accident_severity',
#        'number_of_vehicles', 'number_of_casualties', 'day_of_week', 'time',
#        'local_authority_district', 'local_authority_ons_district',
#        'local_authority_highway', 'first_road_class', 'first_road_number',
#        'road_type', 'speed_limit', 'junction_detail', 'junction_control',
#        'second_road_class', 'second_road_number',
#        'pedestrian_crossing_human_control',
#        'pedestrian_crossing_physical_facilities', 'light_conditions',
#        'weather_conditions', 'road_surface_conditions',
#        'special_conditions_at_site', 'carriageway_hazards',
#        'urban_or_rural_area', 'did_police_officer_attend_scene_of_accident'],
#       dtype='object')

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
X_train.dtypes
# Out:
# longitude                                       float64
# latitude                                        float64
# police_force                                      int64
# number_of_vehicles                                int64
# number_of_casualties                              int64
# day_of_week                                       int64
# time                                              int64
# local_authority_district                       category
# local_authority_ons_district                      int16
# local_authority_highway                           int16
# first_road_class                               category
# first_road_number                              category
# road_type                                      category
# speed_limit                                     float64
# junction_detail                                category
# junction_control                               category
# second_road_class                              category
# ...

# %%
lr.fit(X_train,Y_train)
# Out:
# C:\Users\bchen\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\bchen\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train.head()
# Out:
#         longitude   latitude  police_force  number_of_vehicles  \
# 484171  -0.147489  50.830733            47                   2
# 358143  -0.508465  51.375536            45                   2
# 555586  -1.225555  53.161021            31                   3
# 545141  -0.444252  53.687077            16                   1
# 51062   -1.281776  53.371864            14                   3
#
#         number_of_casualties  day_of_week  time local_authority_district  \
# 484171                     1            3    23                      565
# 358143                     2            5    14                      514
# 555586                     1            5     1                      344
# 545141                     1            7    15                      232
# 51062                      1            4    18                      213
#
#         local_authority_ons_district  local_authority_highway  ...  \
# 484171                            42                       43  ...
# ...

# %%
Y_predict=lr.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
Z=confusion_matrix(Y_test,Y_predict)

# %%
Z
# Out:
# array([[     0,      0,   2427],
#        [     0,      0,  32433],
#        [     0,      0, 144481]], dtype=int64)

# %%
lr.score(X_test,Y_test)
# Out:
# 0.8056216927529121
